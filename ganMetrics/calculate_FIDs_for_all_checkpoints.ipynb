# %%
# add parent dir to syspath
import os,sys,inspect
current_dir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parent_dir = os.path.dirname(current_dir)
root_dir = os.path.dirname(parent_dir)
sys.path.insert(0, parent_dir)

from pathlib import Path
import calculate_FIDs_for_checkpoints
from beep import beep

# %%
# assert model is running on gpu
from tensorflow.python.client import device_lib
devlist = str(device_lib.list_local_devices())
assert "GPU:0" in devlist

# %%
basepath = Path("D:/m2/savedmodels/goals/out_of_vocab/512_2")
models = [
    ###"n64_epochs32",
    #"n128_epochs16",
    #"n256_epochs8",
    "remove3at3"    
]
for model in models:
    CHECKPOINTPATH = basepath / model
    useNewGenerator = True
    calculate_FIDs_for_checkpoints.calculate_FIDs(CHECKPOINTPATH, 1000, epochstart=1, input_synthethic=True, useNewGenerator=useNewGenerator)
# Out:
# C:\Users\andre\jupyter_ws\imageGenerators\load_realdata.py:57: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(txt_path, sep=seperators ,header=None)
# calculating rlts took 16.563529 seconds
# calculating rlts took 12.502213 seconds
# inputimages:
# (1000, 128, 512, 1)
# uint8
# loaded checkpoint:  D:\m2\savedmodels\goals\out_of_vocab\512_2\remove3at3\epoch-1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).disc_A_optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).disc_A_optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).disc_A_optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).disc_A_optimizer.decay
# ...

# %%
beep.play_finished()
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
